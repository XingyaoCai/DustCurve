# %% [markdown]
# 3850-3950 4000-4100

# %%
import os
import pathlib

import warnings
warnings.filterwarnings("ignore")

import FunctionLib as FL
from tqdm import tqdm

import numpy as np
import pandas as pd
import scipy
from scipy.interpolate import interp1d

import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['font.family'] = 'serif'

import astropy
import astropy.units as u

DJAv4Catalog = FL.Spectrum_Catalog()
DJAv4Catalog.load_from_pkl(('./DJAV4.2Catalog.pkl'))
print(DJAv4Catalog.sample_num())
DJAv4Catalog.to_dataframe()
# Out:
# 458
#                    survey_id_subid  \
# 0               snh0pe-v4_4446_102
# 1               snh0pe-v4_4446_143
# 2               snh0pe-v4_4446_285
# 3                snh0pe-v4_4446_29
# 4               snh0pe-v4_4446_123
# ...                            ...
# 43037   glimpse-obs02-v4_9223_9152
# 43038  glimpse-obs02-v4_9223_98001
# 43039  glimpse-obs02-v4_9223_47046
# 43040  glimpse-obs02-v4_9223_45350
# 43041  glimpse-obs02-v4_9223_16199
#
#                                           prism_filepath prism_redshift  \
# 0      /home/xingyaocai/DJAv4.2/snh0pe-v4/snh0pe-v4_p...         0.2259
# 1      /home/xingyaocai/DJAv4.2/snh0pe-v4/snh0pe-v4_p...         1.6318
# 2      /home/xingyaocai/DJAv4.2/snh0pe-v4/snh0pe-v4_p...         0.4446
# 3      /home/xingyaocai/DJAv4.2/snh0pe-v4/snh0pe-v4_p...         1.7834
# 4      /home/xingyaocai/DJAv4.2/snh0pe-v4/snh0pe-v4_p...         1.7855
# ...                                                  ...            ...
# 43037                                               None           None
# 43038                                               None           None
# 43039                                               None           None
# 43040                                               None           None
# 43041                                               None           None
#
#       determined_redshift                                  grating_filepaths  \
# 0                  0.2259  {'g140m-f100lp': '/home/xingyaocai/DJAv4.2/snh...
# 1                  1.6311  {'g140m-f100lp': '/home/xingyaocai/DJAv4.2/snh...
# 2                  0.4462  {'g235m-f170lp': '/home/xingyaocai/DJAv4.2/snh...
# 3                 1.77975  {'g140m-f100lp': '/home/xingyaocai/DJAv4.2/snh...
# 4                  1.7855  {'g140m-f100lp': '/home/xingyaocai/DJAv4.2/snh...
# ...                   ...                                                ...
# 43037              5.5385  {'g395m-f290lp': '/home/xingyaocai/DJAv4.2/gli...
# 43038              2.6322  {'g395m-f290lp': '/home/xingyaocai/DJAv4.2/gli...
# 43039              4.3554  {'g395m-f290lp': '/home/xingyaocai/DJAv4.2/gli...
# 43040              1.3675  {'g395m-f290lp': '/home/xingyaocai/DJAv4.2/gli...
# 43041              3.2858  {'g395m-f290lp': '/home/xingyaocai/DJAv4.2/gli...
#
#                                       grating_redshifts  file_count  \
# 0            {'g140m-f100lp': nan, 'g235m-f170lp': nan}           3
# 1      {'g140m-f100lp': 1.6313, 'g235m-f170lp': 1.6309}           3
# 2      {'g235m-f170lp': 0.4462, 'g140m-f100lp': 0.4462}           3
# 3      {'g140m-f100lp': 1.7799, 'g235m-f170lp': 1.7796}           3
# 4      {'g140m-f100lp': 1.7855, 'g235m-f170lp': 1.7851}           3
# ...                                                 ...         ...
# 43037                          {'g395m-f290lp': 5.5385}           1
# 43038                          {'g395m-f290lp': 2.6322}           1
# 43039                          {'g395m-f290lp': 4.3554}           1
# 43040                          {'g395m-f290lp': 1.3675}           1
# 43041                          {'g395m-f290lp': 3.2858}           1
#
#                                available_filters  \
# 0      {g235m-f170lp, prism-clear, g140m-f100lp}
# 1      {g235m-f170lp, prism-clear, g140m-f100lp}
# 2      {g235m-f170lp, prism-clear, g140m-f100lp}
# 3      {g235m-f170lp, prism-clear, g140m-f100lp}
# 4      {g235m-f170lp, prism-clear, g140m-f100lp}
# ...                                          ...
# 43037                             {g395m-f290lp}
# 43038                             {g395m-f290lp}
# 43039                             {g395m-f290lp}
# 43040                             {g395m-f290lp}
# 43041                             {g395m-f290lp}
#
#                          properties         survey_id  sample_flag  \
# 0      {'redshift_conflict': False}         snh0pe-v4        False
# 1      {'redshift_conflict': False}         snh0pe-v4        False
# 2      {'redshift_conflict': False}         snh0pe-v4        False
# 3      {'redshift_conflict': False}         snh0pe-v4        False
# 4      {'redshift_conflict': False}         snh0pe-v4        False
# ...                             ...               ...          ...
# 43037  {'redshift_conflict': False}  glimpse-obs02-v4        False
# 43038  {'redshift_conflict': False}  glimpse-obs02-v4        False
# 43039  {'redshift_conflict': False}  glimpse-obs02-v4        False
# 43040  {'redshift_conflict': False}  glimpse-obs02-v4        False
# 43041  {'redshift_conflict': False}  glimpse-obs02-v4        False
#
#                                     reason_for_exclusion  \
# 0      [redshift_below_3, redshift_below_3, redshift_...
# 1      [redshift_below_3, redshift_below_3, redshift_...
# 2      [redshift_below_3, redshift_below_3, redshift_...
# 3      [redshift_below_3, redshift_below_3, redshift_...
# 4      [redshift_below_3, redshift_below_3, redshift_...
# ...                                                  ...
# 43037  [no_prism_spectrum, no_prism_spectrum, no_pris...
# 43038  [no_prism_spectrum, no_prism_spectrum, no_pris...
# 43039  [no_prism_spectrum, no_prism_spectrum, no_pris...
# 43040  [no_prism_spectrum, no_prism_spectrum, no_pris...
# 43041  [no_prism_spectrum, no_prism_spectrum, no_pris...
#
#       grating_slitloss_correction grating_within_coverage lines_fit  \
# 0                              {}                      {}        {}
# 1                              {}                      {}        {}
# 2                              {}                      {}        {}
# 3                              {}                      {}        {}
# 4                              {}                      {}        {}
# ...                           ...                     ...       ...
# 43037                          {}                      {}        {}
# 43038                          {}                      {}        {}
# 43039                          {}                      {}        {}
# 43040                          {}                      {}        {}
# 43041                          {}                      {}        {}
#
#       s3fit_result_path line_ratios dust_curve_parameters
# 0                  None          {}                    {}
# 1                  None          {}                    {}
# 2                  None          {}                    {}
# 3                  None          {}                    {}
# 4                  None          {}                    {}
# ...                 ...         ...                   ...
# 43037              None          {}                    {}
# 43038              None          {}                    {}
# 43039              None          {}                    {}
# 43040              None          {}                    {}
# 43041              None          {}                    {}
#
# [43042 rows x 18 columns]

# %%
np.log(10)
# Out:
# np.float64(2.302585092994046)

# %%
no_coverage_num=0

for surveyid_subid, catalog in DJAv4Catalog.catalog_iterator(1000):
    if not catalog['sample_flag']:
        continue

    coverage_flag=False
    prism_spectrum=FL.Load_Spectrum_From_Fits(catalog['prism_filepath'], catalog['determined_redshift'])
    prism_spectrum.set_boundarys(3800*u.AA, 4150*u.AA)
    prism_spectrum.show()

    for key, grating_filepath in catalog['grating_filepaths'].items():

        grating_spectrum=FL.Load_Spectrum_From_Fits(grating_filepath, catalog['determined_redshift'])

        dual_boundarys=grating_spectrum.dual_boundarys()

        if dual_boundarys[0]>3850*u.AA:
            continue
        grating_spectrum.set_boundarys(3800*u.AA, 4150*u.AA)

        if (grating_spectrum.processing_flux_lambda.data-grating_spectrum.processing_flux_nu.data).all()==False:
            continue
        grating_spectrum.show()

        coverage_flag=True
    if not coverage_flag:
        no_coverage_num+=1

# %%
no_coverage_num
