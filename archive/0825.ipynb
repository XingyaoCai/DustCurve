# %% [markdown]
# ## Fitting Uncertainty
# #### Load from function
# #### $$\text{Flux}=A * \sigma * \sqrt{2\pi}$$
# #### $$\sigma_\text{Flux}^2=\left(\frac{\partial \text{Flux}}{\partial A}\right)^2* \sigma_A^2+\left(\frac{\partial \text{Flux}}{\partial \sigma}\right)^2* \sigma_\sigma^2 + 2*\left(\frac{\partial \text{Flux}}{\partial A}\right)\left(\frac{\partial \text{Flux}}{\partial \sigma}\right)*Cov_{A, \sigma}$$
# ---
# ## Flux Uncertainty
# #### 150 AA, 75 for left and 75 for right
# #### 2 FWHM
# #### 20 measurements

# %% [markdown]
# ![snratio.png](attachment:snratio.png)

# %% [markdown]
# ## Uncertainty Propagation
# ### $$\tau_\beta=\frac{\text{Flux}_{H\alpha}}{\text{Flux}_{H\beta}}=\frac{{H\alpha}}{{H\beta}}$$
# ### $$\sigma_\tau^2=\left(\frac{\partial \tau_\beta}{\partial H\alpha}\right)^2*\sigma_{H\alpha}^2+\left(\frac{\partial \tau_\beta}{\partial H\beta}\right)^2*\sigma_{H\beta}^2+2*\left(\frac{\partial \tau_\beta}{\partial H\alpha}\right)\left(\frac{\partial \tau_\beta}{\partial H\beta}\right)Cov_{H\alpha,H\beta}$$

# %% [markdown]
# ![output.png](attachment:output.png)

# %% [markdown]
# ![0.5.png](attachment:0.5.png)

# %% [markdown]
# ![Screenshot 2025-08-25 at 12.57.17.png](<attachment:Screenshot 2025-08-25 at 12.57.17.png>)

# %% [markdown]
# ---

# %% [markdown]
# ## Mean Spectrum

# %% [markdown]
# #### No Normalization
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# #### Normalization at 5500 AA
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ### 16% to 84% flux range
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ### 25% to 75% flux range
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ![image.png](attachment:image.png)
